# %% [markdown]
# # Stock Prediction using CNN

# %%
from utils import *

import pandas as pd
import matplotlib.pylab as plt

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.recurrent import LSTM, GRU
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D, RepeatVector
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.layers.wrappers import Bidirectional
from keras import regularizers
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import *
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.initializers import *

import seaborn as sns

# %% [markdown]
# Inline for jupyter

# %%
# %matplotlib inline

# %%
sns.despine()

# %% [markdown]
# Preprocessing data to a matrix[image format]

# %%
data_original = pd.read_csv('./data/AAPL1216.csv')[::-1]

openp = data_original.ix[:, 'Open'].tolist()
highp = data_original.ix[:, 'High'].tolist()
lowp = data_original.ix[:, 'Low'].tolist()
closep = data_original.ix[:, 'Adj Close'].tolist()
volumep = data_original.ix[:, 'Volume'].tolist()
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys

# %%
WINDOW = 30
EMB_SIZE = 5
STEP = 1
FORECAST = 1

# %%
X, Y = [], []
for i in range(0, len(data_original), STEP): 
    try:
        o = openp[i:i+WINDOW]
        h = highp[i:i+WINDOW]
        l = lowp[i:i+WINDOW]
        c = closep[i:i+WINDOW]
        v = volumep[i:i+WINDOW]

        o = (np.array(o) - np.mean(o)) / np.std(o)
        h = (np.array(h) - np.mean(h)) / np.std(h)
        l = (np.array(l) - np.mean(l)) / np.std(l)
        c = (np.array(c) - np.mean(c)) / np.std(c)
        v = (np.array(v) - np.mean(v)) / np.std(v)

        x_i = closep[i:i+WINDOW]
        y_i = closep[i+WINDOW+FORECAST]  

        last_close = x_i[-1]
        next_close = y_i

        if last_close < next_close:
            y_i = [1, 0]
        else:
            y_i = [0, 1] 

        x_i = np.column_stack((o, h, l, c, v))

    except Exception as e:
        break

    X.append(x_i)
    Y.append(y_i)

# %% [markdown]
# Train Test Split

# %%
X, Y = np.array(X), np.array(Y)
X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], EMB_SIZE))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], EMB_SIZE))

# %% [markdown]
# Model

# %%
model = Sequential()
model.add(Convolution1D(input_shape = (WINDOW, EMB_SIZE),
                        nb_filter=16,
                        filter_length=4,
                        border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dropout(0.5))

model.add(Convolution1D(nb_filter=8,
                        filter_length=4,
                        border_mode='same'))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(64))
model.add(BatchNormalization())
model.add(LeakyReLU())


model.add(Dense(2))
model.add(Activation('softmax'))

opt = Nadam(lr=0.002)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=30, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint(filepath="lolkek.hdf5", verbose=1, save_best_only=True)


model.compile(optimizer=opt, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(kernel_size=4, input_shape=(30, 5), padding="same", filters=16)`
#   """
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(kernel_size=4, padding="same", filters=8)`
#   if sys.path[0] == '':

# %%
history = model.fit(X_train, Y_train, 
          nb_epoch = 100, 
          batch_size = 128, 
          verbose=1, 
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr, checkpointer],
          shuffle=True)
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:7: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   import sys
# Train on 877 samples, validate on 98 samples
# Epoch 1/100
# 877/877 [==============================] - 1s 2ms/step - loss: 0.8883 - acc: 0.4835 - val_loss: 0.7425 - val_acc: 0.4694
#
# Epoch 00001: val_loss improved from inf to 0.74254, saving model to lolkek.hdf5
# Epoch 2/100
# 877/877 [==============================] - 0s 85us/step - loss: 0.7840 - acc: 0.5097 - val_loss: 0.7340 - val_acc: 0.4490
#
# Epoch 00002: val_loss improved from 0.74254 to 0.73395, saving model to lolkek.hdf5
# Epoch 3/100
# 877/877 [==============================] - 0s 88us/step - loss: 0.7724 - acc: 0.5211 - val_loss: 0.7347 - val_acc: 0.4286
#
# Epoch 00003: val_loss did not improve from 0.73395
# Epoch 4/100
# 877/877 [==============================] - 0s 89us/step - loss: 0.7146 - acc: 0.5519 - val_loss: 0.7552 - val_acc: 0.4082
#
# Epoch 00004: val_loss did not improve from 0.73395
# Epoch 5/100
# 877/877 [==============================] - 0s 86us/step - loss: 0.7302 - acc: 0.5428 - val_loss: 0.7490 - val_acc: 0.4184
#
# Epoch 00005: val_loss did not improve from 0.73395
# Epoch 6/100
# 877/877 [==============================] - 0s 89us/step - loss: 0.6887 - acc: 0.5827 - val_loss: 0.7564 - val_acc: 0.4490
#
# Epoch 00006: val_loss did not improve from 0.73395
# Epoch 7/100
# 877/877 [==============================] - 0s 88us/step - loss: 0.6965 - acc: 0.5747 - val_loss: 0.7385 - val_acc: 0.4388
#
# Epoch 00007: val_loss did not improve from 0.73395
# Epoch 8/100
# 877/877 [==============================] - 0s 89us/step - loss: 0.6990 - acc: 0.5542 - val_loss: 0.7359 - val_acc: 0.4490
#
# Epoch 00008: val_loss did not improve from 0.73395
# Epoch 9/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.6987 - acc: 0.5564 - val_loss: 0.7408 - val_acc: 0.4592
#
# Epoch 00009: val_loss did not improve from 0.73395
# Epoch 10/100
# 877/877 [==============================] - 0s 102us/step - loss: 0.6929 - acc: 0.5587 - val_loss: 0.7452 - val_acc: 0.4592
#
# Epoch 00010: val_loss did not improve from 0.73395
# Epoch 11/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.7100 - acc: 0.5382 - val_loss: 0.7535 - val_acc: 0.4592
#
# Epoch 00011: val_loss did not improve from 0.73395
# Epoch 12/100
# 877/877 [==============================] - 0s 72us/step - loss: 0.6828 - acc: 0.5713 - val_loss: 0.7568 - val_acc: 0.4388
#
# Epoch 00012: val_loss did not improve from 0.73395
# Epoch 13/100
# 877/877 [==============================] - 0s 69us/step - loss: 0.6928 - acc: 0.5735 - val_loss: 0.7543 - val_acc: 0.4592
#
# Epoch 00013: val_loss did not improve from 0.73395
# Epoch 14/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6907 - acc: 0.5633 - val_loss: 0.7347 - val_acc: 0.5000
#
# Epoch 00014: val_loss did not improve from 0.73395
# Epoch 15/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6716 - acc: 0.5804 - val_loss: 0.7257 - val_acc: 0.5102
#
# Epoch 00015: val_loss improved from 0.73395 to 0.72573, saving model to lolkek.hdf5
# Epoch 16/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.6835 - acc: 0.5815 - val_loss: 0.7321 - val_acc: 0.4694
#
# Epoch 00016: val_loss did not improve from 0.72573
# Epoch 17/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6905 - acc: 0.5553 - val_loss: 0.7326 - val_acc: 0.4694
#
# Epoch 00017: val_loss did not improve from 0.72573
# Epoch 18/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.6747 - acc: 0.5804 - val_loss: 0.7248 - val_acc: 0.5000
#
# Epoch 00018: val_loss improved from 0.72573 to 0.72480, saving model to lolkek.hdf5
# Epoch 19/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6618 - acc: 0.6180 - val_loss: 0.7356 - val_acc: 0.4592
#
# Epoch 00019: val_loss did not improve from 0.72480
# Epoch 20/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6714 - acc: 0.5918 - val_loss: 0.7271 - val_acc: 0.5306
#
# Epoch 00020: val_loss did not improve from 0.72480
# Epoch 21/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6727 - acc: 0.5804 - val_loss: 0.7350 - val_acc: 0.5102
#
# Epoch 00021: val_loss did not improve from 0.72480
# Epoch 22/100
# 877/877 [==============================] - 0s 73us/step - loss: 0.6679 - acc: 0.6009 - val_loss: 0.7366 - val_acc: 0.5204
#
# Epoch 00022: val_loss did not improve from 0.72480
# Epoch 23/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6648 - acc: 0.5952 - val_loss: 0.7335 - val_acc: 0.4592
#
# Epoch 00023: val_loss did not improve from 0.72480
# Epoch 24/100
# 877/877 [==============================] - 0s 74us/step - loss: 0.6719 - acc: 0.5872 - val_loss: 0.7305 - val_acc: 0.5204
#
# Epoch 00024: val_loss did not improve from 0.72480
# Epoch 25/100
# 877/877 [==============================] - 0s 90us/step - loss: 0.6596 - acc: 0.6021 - val_loss: 0.7306 - val_acc: 0.5204
#
# Epoch 00025: val_loss did not improve from 0.72480
# Epoch 26/100
# 877/877 [==============================] - 0s 98us/step - loss: 0.6535 - acc: 0.5941 - val_loss: 0.7286 - val_acc: 0.5102
#
# Epoch 00026: val_loss did not improve from 0.72480
# Epoch 27/100
# 877/877 [==============================] - 0s 99us/step - loss: 0.6592 - acc: 0.6112 - val_loss: 0.7226 - val_acc: 0.5000
#
# Epoch 00027: val_loss improved from 0.72480 to 0.72257, saving model to lolkek.hdf5
# Epoch 28/100
# 877/877 [==============================] - 0s 106us/step - loss: 0.6645 - acc: 0.6055 - val_loss: 0.7205 - val_acc: 0.4898
#
# Epoch 00028: val_loss improved from 0.72257 to 0.72051, saving model to lolkek.hdf5
# Epoch 29/100
# 877/877 [==============================] - 0s 129us/step - loss: 0.6580 - acc: 0.6226 - val_loss: 0.7203 - val_acc: 0.5408
#
# Epoch 00029: val_loss improved from 0.72051 to 0.72033, saving model to lolkek.hdf5
# Epoch 30/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6627 - acc: 0.5815 - val_loss: 0.7224 - val_acc: 0.5204
#
# Epoch 00030: val_loss did not improve from 0.72033
# Epoch 31/100
# 877/877 [==============================] - 0s 83us/step - loss: 0.6486 - acc: 0.6192 - val_loss: 0.7205 - val_acc: 0.5918
#
# Epoch 00031: val_loss did not improve from 0.72033
# Epoch 32/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.6460 - acc: 0.6043 - val_loss: 0.7210 - val_acc: 0.5612
#
# Epoch 00032: val_loss did not improve from 0.72033
# Epoch 33/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.6506 - acc: 0.6237 - val_loss: 0.7087 - val_acc: 0.6020
#
# Epoch 00033: val_loss improved from 0.72033 to 0.70874, saving model to lolkek.hdf5
# Epoch 34/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6390 - acc: 0.6534 - val_loss: 0.7077 - val_acc: 0.5816
#
# Epoch 00034: val_loss improved from 0.70874 to 0.70766, saving model to lolkek.hdf5
# Epoch 35/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.6577 - acc: 0.6066 - val_loss: 0.7116 - val_acc: 0.5102
#
# Epoch 00035: val_loss did not improve from 0.70766
# Epoch 36/100
# 877/877 [==============================] - 0s 88us/step - loss: 0.6441 - acc: 0.6237 - val_loss: 0.7108 - val_acc: 0.5714
#
# Epoch 00036: val_loss did not improve from 0.70766
# Epoch 37/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.6540 - acc: 0.6078 - val_loss: 0.7049 - val_acc: 0.5816
#
# Epoch 00037: val_loss improved from 0.70766 to 0.70490, saving model to lolkek.hdf5
# Epoch 38/100
# 877/877 [==============================] - 0s 88us/step - loss: 0.6402 - acc: 0.6249 - val_loss: 0.7054 - val_acc: 0.5714
#
# Epoch 00038: val_loss did not improve from 0.70490
# Epoch 39/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.6340 - acc: 0.6454 - val_loss: 0.7005 - val_acc: 0.5612
#
# Epoch 00039: val_loss improved from 0.70490 to 0.70053, saving model to lolkek.hdf5
# Epoch 40/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6583 - acc: 0.6055 - val_loss: 0.6971 - val_acc: 0.5510
#
# Epoch 00040: val_loss improved from 0.70053 to 0.69711, saving model to lolkek.hdf5
# Epoch 41/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6298 - acc: 0.6374 - val_loss: 0.7044 - val_acc: 0.5510
#
# Epoch 00041: val_loss did not improve from 0.69711
# Epoch 42/100
# 877/877 [==============================] - 0s 74us/step - loss: 0.6394 - acc: 0.6203 - val_loss: 0.7164 - val_acc: 0.5306
# Epoch 00042: val_loss did not improve from 0.69711
# Epoch 43/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6462 - acc: 0.6249 - val_loss: 0.7116 - val_acc: 0.5306
#
# Epoch 00043: val_loss did not improve from 0.69711
# Epoch 44/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6336 - acc: 0.6420 - val_loss: 0.7099 - val_acc: 0.5102
#
# Epoch 00044: val_loss did not improve from 0.69711
# Epoch 45/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6412 - acc: 0.6123 - val_loss: 0.7061 - val_acc: 0.5102
#
# Epoch 00045: val_loss did not improve from 0.69711
# Epoch 46/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6447 - acc: 0.6203 - val_loss: 0.6991 - val_acc: 0.5102
#
# Epoch 00046: val_loss did not improve from 0.69711
# Epoch 47/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6383 - acc: 0.6374 - val_loss: 0.6855 - val_acc: 0.5816
#
# Epoch 00047: val_loss improved from 0.69711 to 0.68554, saving model to lolkek.hdf5
# Epoch 48/100
# 877/877 [==============================] - 0s 89us/step - loss: 0.6285 - acc: 0.6477 - val_loss: 0.6855 - val_acc: 0.5918
#
# Epoch 00048: val_loss improved from 0.68554 to 0.68553, saving model to lolkek.hdf5
# Epoch 49/100
# 877/877 [==============================] - 0s 84us/step - loss: 0.6360 - acc: 0.6294 - val_loss: 0.6879 - val_acc: 0.5918
#
# Epoch 00049: val_loss did not improve from 0.68553
# Epoch 50/100
# 877/877 [==============================] - 0s 91us/step - loss: 0.6373 - acc: 0.6340 - val_loss: 0.6926 - val_acc: 0.5612
#
# Epoch 00050: val_loss did not improve from 0.68553
# Epoch 51/100
# 877/877 [==============================] - 0s 90us/step - loss: 0.6191 - acc: 0.6545 - val_loss: 0.6892 - val_acc: 0.5918
#
# Epoch 00051: val_loss did not improve from 0.68553
# Epoch 52/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.6289 - acc: 0.6477 - val_loss: 0.6828 - val_acc: 0.6122
#
# Epoch 00052: val_loss improved from 0.68553 to 0.68277, saving model to lolkek.hdf5
# Epoch 53/100
# 877/877 [==============================] - 0s 117us/step - loss: 0.6376 - acc: 0.6214 - val_loss: 0.6806 - val_acc: 0.6020
#
# Epoch 00053: val_loss improved from 0.68277 to 0.68062, saving model to lolkek.hdf5
# Epoch 54/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6298 - acc: 0.6408 - val_loss: 0.6821 - val_acc: 0.5714
#
# Epoch 00054: val_loss did not improve from 0.68062
# Epoch 55/100
# 877/877 [==============================] - 0s 81us/step - loss: 0.6307 - acc: 0.6522 - val_loss: 0.6840 - val_acc: 0.5714
#
# Epoch 00055: val_loss did not improve from 0.68062
# Epoch 56/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6375 - acc: 0.6271 - val_loss: 0.6870 - val_acc: 0.5612
#
# Epoch 00056: val_loss did not improve from 0.68062
# Epoch 57/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.6344 - acc: 0.6214 - val_loss: 0.6762 - val_acc: 0.5510
#
# Epoch 00057: val_loss improved from 0.68062 to 0.67621, saving model to lolkek.hdf5
# Epoch 58/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6085 - acc: 0.6602 - val_loss: 0.6863 - val_acc: 0.6020
#
# Epoch 00058: val_loss did not improve from 0.67621
# Epoch 59/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6159 - acc: 0.6522 - val_loss: 0.7040 - val_acc: 0.5714
#
# Epoch 00059: val_loss did not improve from 0.67621
# Epoch 60/100
# 877/877 [==============================] - 0s 73us/step - loss: 0.6339 - acc: 0.6420 - val_loss: 0.7050 - val_acc: 0.5408
#
# Epoch 00060: val_loss did not improve from 0.67621
# Epoch 61/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6179 - acc: 0.6579 - val_loss: 0.6930 - val_acc: 0.5510
#
# Epoch 00061: val_loss did not improve from 0.67621
# Epoch 62/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6097 - acc: 0.6670 - val_loss: 0.6953 - val_acc: 0.5612
#
# Epoch 00062: val_loss did not improve from 0.67621
# Epoch 63/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6107 - acc: 0.6705 - val_loss: 0.7028 - val_acc: 0.5306
#
# Epoch 00063: val_loss did not improve from 0.67621
# Epoch 64/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6146 - acc: 0.6420 - val_loss: 0.6996 - val_acc: 0.5714
#
# Epoch 00064: val_loss did not improve from 0.67621
# Epoch 65/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.6108 - acc: 0.6716 - val_loss: 0.6805 - val_acc: 0.5306
#
# Epoch 00065: val_loss did not improve from 0.67621
# Epoch 66/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.6195 - acc: 0.6591 - val_loss: 0.6824 - val_acc: 0.5918
#
# Epoch 00066: val_loss did not improve from 0.67621
# Epoch 67/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6207 - acc: 0.6408 - val_loss: 0.6874 - val_acc: 0.5612
#
# Epoch 00067: val_loss did not improve from 0.67621
# Epoch 68/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.6030 - acc: 0.6602 - val_loss: 0.6798 - val_acc: 0.5714
#
# Epoch 00068: val_loss did not improve from 0.67621
# Epoch 69/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6188 - acc: 0.6693 - val_loss: 0.6734 - val_acc: 0.5918
#
# Epoch 00069: val_loss improved from 0.67621 to 0.67338, saving model to lolkek.hdf5
# Epoch 70/100
# 877/877 [==============================] - 0s 81us/step - loss: 0.6155 - acc: 0.6534 - val_loss: 0.6684 - val_acc: 0.5816
#
# Epoch 00070: val_loss improved from 0.67338 to 0.66837, saving model to lolkek.hdf5
# Epoch 71/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.5925 - acc: 0.6853 - val_loss: 0.6879 - val_acc: 0.5510
#
# Epoch 00071: val_loss did not improve from 0.66837
# Epoch 72/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.5993 - acc: 0.6967 - val_loss: 0.6787 - val_acc: 0.6020
#
# Epoch 00072: val_loss did not improve from 0.66837
# Epoch 73/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.6156 - acc: 0.6648 - val_loss: 0.6837 - val_acc: 0.5918
#
# Epoch 00073: val_loss did not improve from 0.66837
# Epoch 74/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.6061 - acc: 0.6591 - val_loss: 0.6831 - val_acc: 0.5918
#
# Epoch 00074: val_loss did not improve from 0.66837
# Epoch 75/100
# 877/877 [==============================] - 0s 80us/step - loss: 0.5882 - acc: 0.6864 - val_loss: 0.6860 - val_acc: 0.5816
#
# Epoch 00075: val_loss did not improve from 0.66837
# Epoch 76/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.6173 - acc: 0.6636 - val_loss: 0.6689 - val_acc: 0.5918
#
# Epoch 00076: val_loss did not improve from 0.66837
# Epoch 77/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6077 - acc: 0.6773 - val_loss: 0.6763 - val_acc: 0.5612
#
# Epoch 00077: val_loss did not improve from 0.66837
# Epoch 78/100
# 877/877 [==============================] - 0s 74us/step - loss: 0.6124 - acc: 0.6648 - val_loss: 0.6855 - val_acc: 0.5714
#
# Epoch 00078: val_loss did not improve from 0.66837
# Epoch 79/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.5855 - acc: 0.6796 - val_loss: 0.7018 - val_acc: 0.5408
#
# Epoch 00079: val_loss did not improve from 0.66837
# Epoch 80/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5990 - acc: 0.6739 - val_loss: 0.6927 - val_acc: 0.5816
#
# Epoch 00080: val_loss did not improve from 0.66837
# Epoch 81/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.5825 - acc: 0.7035 - val_loss: 0.6818 - val_acc: 0.5918
#
# Epoch 00081: val_loss did not improve from 0.66837
# Epoch 82/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.6004 - acc: 0.6796 - val_loss: 0.6765 - val_acc: 0.5918
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.0018000000854954123.
#
# Epoch 00082: val_loss did not improve from 0.66837
# Epoch 83/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.5683 - acc: 0.7081 - val_loss: 0.6760 - val_acc: 0.6020
#
# Epoch 00083: val_loss did not improve from 0.66837
# Epoch 84/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5998 - acc: 0.6716 - val_loss: 0.6687 - val_acc: 0.5918
#
# Epoch 00084: val_loss did not improve from 0.66837
# Epoch 85/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.5899 - acc: 0.6762 - val_loss: 0.6718 - val_acc: 0.6224
#
# Epoch 00085: val_loss did not improve from 0.66837
# Epoch 86/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5871 - acc: 0.6819 - val_loss: 0.6710 - val_acc: 0.5510
#
# Epoch 00086: val_loss did not improve from 0.66837
# Epoch 87/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.5768 - acc: 0.7024 - val_loss: 0.6616 - val_acc: 0.6327
#
# Epoch 00087: val_loss improved from 0.66837 to 0.66158, saving model to lolkek.hdf5
# Epoch 88/100
# 877/877 [==============================] - 0s 82us/step - loss: 0.5914 - acc: 0.6682 - val_loss: 0.6757 - val_acc: 0.6020
#
# Epoch 00088: val_loss did not improve from 0.66158
# Epoch 89/100
# 877/877 [==============================] - 0s 81us/step - loss: 0.5800 - acc: 0.6978 - val_loss: 0.6750 - val_acc: 0.6429
#
# Epoch 00089: val_loss did not improve from 0.66158
# Epoch 90/100
# 877/877 [==============================] - 0s 81us/step - loss: 0.5824 - acc: 0.7047 - val_loss: 0.6671 - val_acc: 0.6327
#
# Epoch 00090: val_loss did not improve from 0.66158
# Epoch 91/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.5770 - acc: 0.6670 - val_loss: 0.6600 - val_acc: 0.6531
#
# Epoch 00091: val_loss improved from 0.66158 to 0.66001, saving model to lolkek.hdf5
# Epoch 92/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5687 - acc: 0.7058 - val_loss: 0.6716 - val_acc: 0.6429
#
# Epoch 00092: val_loss did not improve from 0.66001
# Epoch 93/100
# 877/877 [==============================] - 0s 81us/step - loss: 0.5790 - acc: 0.6967 - val_loss: 0.6845 - val_acc: 0.6122
#
# Epoch 00093: val_loss did not improve from 0.66001
# Epoch 94/100
# 877/877 [==============================] - 0s 76us/step - loss: 0.5614 - acc: 0.7241 - val_loss: 0.6812 - val_acc: 0.6429
#
# Epoch 00094: val_loss did not improve from 0.66001
# Epoch 95/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5886 - acc: 0.6944 - val_loss: 0.6805 - val_acc: 0.6122
#
# Epoch 00095: val_loss did not improve from 0.66001
# Epoch 96/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5877 - acc: 0.6921 - val_loss: 0.6734 - val_acc: 0.5816
#
# Epoch 00096: val_loss did not improve from 0.66001
# Epoch 97/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.5726 - acc: 0.7058 - val_loss: 0.6711 - val_acc: 0.6020
#
# Epoch 00097: val_loss did not improve from 0.66001
# Epoch 98/100
# 877/877 [==============================] - 0s 78us/step - loss: 0.5696 - acc: 0.7047 - val_loss: 0.6680 - val_acc: 0.5816
#
# Epoch 00098: val_loss did not improve from 0.66001
# Epoch 99/100
# 877/877 [==============================] - 0s 75us/step - loss: 0.5635 - acc: 0.7047 - val_loss: 0.6728 - val_acc: 0.5816
#
# Epoch 00099: val_loss did not improve from 0.66001
# Epoch 100/100
# 877/877 [==============================] - 0s 77us/step - loss: 0.5736 - acc: 0.6910 - val_loss: 0.6675 - val_acc: 0.5714
#
# Epoch 00100: val_loss did not improve from 0.66001

# %% [markdown]
# Confusion Matrix over Test Data

# %%
model.load_weights("lolkek.hdf5")
pred = model.predict(np.array(X_test))

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
C = confusion_matrix([np.argmax(y) for y in Y_test], [np.argmax(y) for y in pred])

print (C / C.astype(np.float).sum(axis=1))
# Out:
# [[0.81632653 0.18367347]
#  [0.51020408 0.48979592]]

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
